# %% [markdown]
# # Pandas 0 Tutorial

# %% [markdown]
# ### Importing libraries

# %% [markdown]
# Use *pip install pandas* or *conda install pandas*

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Basic Syntax

# %% [markdown]
# #### Series
#
# Series are essentially a column in a table. It can have a title and custom indices

# %%
series = pd.Series([20,21,300],name = 'numbers')
series
# Out:
# 0     20
# 1     21
# 2    300
# Name: numbers, dtype: int64

# %% [markdown]
# It can be spliced like a list in python

# %%
series[0]
# Out:
# 20

# %%
series[0:2] #this will create another series
# Out:
# 0    20
# 1    21
# Name: numbers, dtype: int64

# %% [markdown]
# #### The dataframe

# %%
data = {"a":[1,2,3], "b":[4,5,6], "c":[7,8,9]} # this is known as a dictionary
df = pd.DataFrame(data)
df
# Out:
#    a  b  c
# 0  1  4  7
# 1  2  5  8
# 2  3  6  9

# %% [markdown]
# Combining data along columns

# %%
col_df = pd.concat([series,df],axis=1) #axis = 1 means concatinate along the columns
col_df
# Out:
#    numbers  a  b  c
# 0       20  1  4  7
# 1       21  2  5  8
# 2      300  3  6  9

# %%
new_row = pd.DataFrame([[13,14,15]],columns = ['a','b','c'])
new_row
# Out:
#     a   b   c
# 0  13  14  15

# %% [markdown]
# Combining data along rows

# %%
row_df = pd.concat([df,new_row],axis=0) #axis = 0 means concatinate along the rows
row_df
# Out:
#     a   b   c
# 0   1   4   7
# 1   2   5   8
# 2   3   6   9
# 0  13  14  15

# %% [markdown]
# Reset index

# %%
row_df.reset_index(drop=True,inplace=True) #drop=True means drop the old index
row_df
# Out:
#     a   b   c
# 0   1   4   7
# 1   2   5   8
# 2   3   6   9
# 3  13  14  15

# %% [markdown]
# Adding new columns

# %%
names = ['Mungo','Greg','Balthazar']
col_df['Names'] = names
col_df
# Out:
#    numbers  a  b  c      Names
# 0       20  1  4  7      Mungo
# 1       21  2  5  8       Greg
# 2      300  3  6  9  Balthazar

# %% [markdown]
# Removing columns

# %%
col_df.drop(['a','b','c'],axis=1,inplace=True) #axis = 1 means drop the column
col_df
# Out:
#    numbers      Names
# 0       20      Mungo
# 1       21       Greg
# 2      300  Balthazar

# %% [markdown]
# Renaming columns

# %%
col_df.rename(columns={'numbers':'Age'},inplace=True)
col_df
# Out:
#    Age      Names
# 0   20      Mungo
# 1   21       Greg
# 2  300  Balthazar

# %% [markdown]
# *Exercise 1: Add your name and age to col_df as a new row*

# %%
new_row1 = pd.DataFrame([[20,'Hazel']],columns = ['Age','Names'])
new_df = pd.concat([col_df,new_row1],axis=0) #axis = 0 means concatinate along the rows
new_df
# Out:
#    Age      Names
# 0   20      Mungo
# 1   21       Greg
# 2  300  Balthazar
# 0   20      Hazel

# %% [markdown]
# *Exercise 2: Add a new column called 'Surname', with a made up surname for each character*

# %%
sur = ['aaa','bbb','ccc','ddd']
new_df['Surname'] = sur
new_df

## new_df['Surname'] = ['aaa','bbb','ccc','ddd']
# Out:
#    Age      Names Surname
# 0   20      Mungo     aaa
# 1   21       Greg     bbb
# 2  300  Balthazar     ccc
# 0   20      Hazel     ddd

# %% [markdown]
# #### External data

# %% [markdown]
# The head of all dataframes is taken for easier viewing

# %%
real_estate = pd.read_csv("real_estate_tutorial.csv")

# %%
real_estate.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9999 entries, 0 to 9998
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Serial Number     9999 non-null   int64
#  1   List Year         9999 non-null   int64
#  2   Date Recorded     9999 non-null   object
#  3   Town              9999 non-null   object
#  4   Address           9999 non-null   object
#  5   Assessed Value    9999 non-null   int64
#  6   Sale Amount       9999 non-null   float64
#  7   Sales Ratio       9999 non-null   float64
#  8   Property Type     9871 non-null   object
#  9   Residential Type  8925 non-null   object
#  10  Non Use Code      2378 non-null   object
#  11  Assessor Remarks  2328 non-null   object
#  12  OPM remarks       436 non-null    object
#  13  Location          4622 non-null   object
# dtypes: float64(2), int64(3), object(9)
# memory usage: 1.1+ MB

# %% [markdown]
# Number of null values in each column

# %%
real_estate.isna().sum()
# Out:
# Serial Number          0
# List Year              0
# Date Recorded          0
# Town                   0
# Address                0
# Assessed Value         0
# Sale Amount            0
# Sales Ratio            0
# Property Type        128
# Residential Type    1074
# Non Use Code        7621
# Assessor Remarks    7671
# OPM remarks         9563
# Location            5377
# dtype: int64

# %% [markdown]
# Selecting part of dataframe

# %%
real_estate.head() #returns the first 5 rows
# Out:
#    Serial Number  List Year Date Recorded     Town                Address  \
# 0        2020348       2020    09/13/2021  Ansonia        230 WAKELEE AVE
# 1          20002       2020     10/2/2020  Ashford        390 TURNPIKE RD
# 2         200212       2020      3/9/2021     Avon       5 CHESTNUT DRIVE
# 3         200243       2020    04/13/2021     Avon  111 NORTHINGTON DRIVE
# 4         200377       2020      7/2/2021     Avon     70 FAR HILLS DRIVE
#
#    Assessed Value  Sale Amount  Sales Ratio Property Type Residential Type  \
# 0          150500     325000.0       0.4630    Commercial              NaN
# 1          253000     430000.0       0.5883   Residential    Single Family
# 2          130400     179900.0       0.7248   Residential            Condo
# 3          619290     890000.0       0.6958   Residential    Single Family
# 4          862330    1447500.0       0.5957   Residential    Single Family
#
#   Non Use Code Assessor Remarks OPM remarks Location
# 0          NaN              NaN         NaN      NaN
# 1          NaN              NaN         NaN      NaN
# 2          NaN              NaN         NaN      NaN
# 3          NaN              NaN         NaN      NaN
# 4          NaN              NaN         NaN      NaN

# %%
real_estate[['Serial Number','List Year']].head() #columns can be accessed by name
# Out:
#    Serial Number  List Year
# 0        2020348       2020
# 1          20002       2020
# 2         200212       2020
# 3         200243       2020
# 4         200377       2020

# %%
real_estate.iloc[0:,0:2].head() #or using iloc
# Out:
#    Serial Number  List Year
# 0        2020348       2020
# 1          20002       2020
# 2         200212       2020
# 3         200243       2020
# 4         200377       2020

# %%
real_estate.iloc[0,0] #iloc is used to select rows and columns by their index location
# Out:
# 2020348

# %%
real_estate[real_estate['List Year']==2020].head() #selecting rows based on a condition
# Out:
#    Serial Number  List Year Date Recorded     Town                Address  \
# 0        2020348       2020    09/13/2021  Ansonia        230 WAKELEE AVE
# 1          20002       2020     10/2/2020  Ashford        390 TURNPIKE RD
# 2         200212       2020      3/9/2021     Avon       5 CHESTNUT DRIVE
# 3         200243       2020    04/13/2021     Avon  111 NORTHINGTON DRIVE
# 4         200377       2020      7/2/2021     Avon     70 FAR HILLS DRIVE
#
#    Assessed Value  Sale Amount  Sales Ratio Property Type Residential Type  \
# 0          150500     325000.0       0.4630    Commercial              NaN
# 1          253000     430000.0       0.5883   Residential    Single Family
# 2          130400     179900.0       0.7248   Residential            Condo
# 3          619290     890000.0       0.6958   Residential    Single Family
# 4          862330    1447500.0       0.5957   Residential    Single Family
#
#   Non Use Code Assessor Remarks OPM remarks Location
# 0          NaN              NaN         NaN      NaN
# 1          NaN              NaN         NaN      NaN
# 2          NaN              NaN         NaN      NaN
# 3          NaN              NaN         NaN      NaN
# 4          NaN              NaN         NaN      NaN

# %%
real_estate['Town'][real_estate['List Year']==2020].head() #selecting a column based on a condition
# Out:
# 0    Ansonia
# 1    Ashford
# 2       Avon
# 3       Avon
# 4       Avon
# Name: Town, dtype: object

# %% [markdown]
# *Exercise 3: Show the address of all commercial properties*

# %%
real_estate['Address'][real_estate['Property Type']=='Commercial'].to_frame()
# Out:
#                   Address
# 0         230 WAKELEE AVE
# 8             23 AMITY RD
# 13       119 MONTOWESE ST
# 29            131 KENT RD
# 31          1467 SOUTH ST
# ...                   ...
# 9867      140 TRUMBULL ST
# 9875       246 FEDERAL RD
# 9913  44 OLD RIDGEBURY RD
# 9946           59 WEST ST
# 9995          50 DRIVEWAY
#
# [342 rows x 1 columns]

# %% [markdown]
# *Exercise 4: Show all data for properties that are in Avon*

# %%
real_estate[real_estate['Town']=='Avon']
# Out:
#       Serial Number  List Year Date Recorded  Town                Address  \
# 2            200212       2020      3/9/2021  Avon       5 CHESTNUT DRIVE
# 3            200243       2020    04/13/2021  Avon  111 NORTHINGTON DRIVE
# 4            200377       2020      7/2/2021  Avon     70 FAR HILLS DRIVE
# 5            200109       2020     12/9/2020  Avon     57 FAR HILLS DRIVE
# 93            10530       2001     9/12/2002  Avon            1 PUTNAM LN
# ...             ...        ...           ...   ...                    ...
# 9798         200225       2020    03/26/2021  Avon    38 COLD SPRING ROAD
# 9821         200398       2020    07/15/2021  Avon       71 OLD WOOD ROAD
# 9880         200074       2020    11/17/2020  Avon      31 CHEPACHET ROAD
# 9905         200472       2020    08/19/2021  Avon   12 CENTERBROOK COURT
# 9967         200499       2020      9/3/2021  Avon       2 DEEPWOOD DRIVE
#
#       Assessed Value  Sale Amount  Sales Ratio Property Type Residential Type  \
# 2             130400     179900.0       0.7248   Residential            Condo
# 3             619290     890000.0       0.6958   Residential    Single Family
# 4             862330    1447500.0       0.5957   Residential    Single Family
# 5             847520    1250000.0       0.6780   Residential    Single Family
# 93             97300     200000.0       0.4865           NaN              NaN
# ...              ...          ...          ...           ...              ...
# 9798          290410     525000.0       0.5531   Residential    Single Family
# 9821          450510     800000.0       0.5631   Residential    Single Family
# 9880          216680     365000.0       0.5936   Residential    Single Family
# 9905          191290     300000.0       0.6376   Residential            Condo
# 9967          213930     400000.0       0.5348   Residential    Single Family
#
#      Non Use Code Assessor Remarks OPM remarks                    Location
# 2             NaN              NaN         NaN                         NaN
# 3             NaN              NaN         NaN                         NaN
# 4             NaN              NaN         NaN                         NaN
# 5             NaN              NaN         NaN                         NaN
# 93            NaN              NaN         NaN                         NaN
# ...           ...              ...         ...                         ...
# 9798          NaN              NaN         NaN  POINT (-72.87822 41.80228)
# 9821  01 - Family              NaN         NaN                         NaN
# 9880          NaN              NaN         NaN                         NaN
# 9905          NaN              NaN         NaN  POINT (-72.88741 41.77122)
# 9967          NaN              NaN         NaN  POINT (-72.91474 41.79676)
#
# [188 rows x 14 columns]

# %% [markdown]
# *Exercise 5: Show the first 10 rows of the sales ratio and the address in one dataframe*

# %%
real_estate[['Sales Ratio','Address']].head(10)

## .iloc[0:10]
# Out:
#    Sales Ratio                Address
# 0       0.4630        230 WAKELEE AVE
# 1       0.5883        390 TURNPIKE RD
# 2       0.7248       5 CHESTNUT DRIVE
# 3       0.6958  111 NORTHINGTON DRIVE
# 4       0.5957     70 FAR HILLS DRIVE
# 5       0.6780     57 FAR HILLS DRIVE
# 6       1.8015    1539 FARMINGTON AVE
# 7       0.6081      216 WATCH HILL RD
# 8       0.6427            23 AMITY RD
# 9       0.5115      16 DEEPWOOD DRIVE
